# %%
str ="abcd"
print(sorted(str))
# Out:
# ['a', 'b', 'c', 'd']

# %%
dict = {"vegetable": ["carrot", "broccoli"], "fruit": ["apple", "banana"], "drink": ["water", "juice"]}
print(dict, '\n', list(dict.items()), '\n', list(dict.keys()), '\n', list(dict.values()), '\n', list(enumerate(dict.items())), '\n', list(enumerate(dict.keys())), '\n', list(enumerate(dict.values())))
# Out:
# {'vegetable': ['carrot', 'broccoli'], 'fruit': ['apple', 'banana'], 'drink': ['water', 'juice']}
#  [('vegetable', ['carrot', 'broccoli']), ('fruit', ['apple', 'banana']), ('drink', ['water', 'juice'])]
#  ['vegetable', 'fruit', 'drink']
#  [['carrot', 'broccoli'], ['apple', 'banana'], ['water', 'juice']]
#  [(0, ('vegetable', ['carrot', 'broccoli'])), (1, ('fruit', ['apple', 'banana'])), (2, ('drink', ['water', 'juice']))]
#  [(0, 'vegetable'), (1, 'fruit'), (2, 'drink')]
#  [(0, ['carrot', 'broccoli']), (1, ['apple', 'banana']), (2, ['water', 'juice'])]

# %%
a = [1,2,3,4,1]
print(set(a))
# Out:
# {1, 2, 3, 4}
